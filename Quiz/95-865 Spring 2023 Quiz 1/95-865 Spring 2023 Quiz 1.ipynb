# %% [markdown]
# # 95-865 Spring 2023 Quiz 1
#
# This is an 80 minute exam. **We will only grade what is submitted via Canvas before the submission system closes.**
#
# You must fill in your name and your Andrew ID for this quiz to be graded. Moreover, filling out your name and Andrew ID below will serve as your agreement with us, the course staff, that you did not collaborate with anyone on this exam and that what you submit is truly your own individual work and not that of anyone else. Violations found will result in severe penalties.
#
# **If you use resources from 95-865 (such as lecture slides, demos, homework solutions, past quiz solutions, etc), you do not have to cite these resources. However, if you use resources external to 95-865 (e.g., Stack Overflow, ChatGPT), please cite these resources.**

# %% [markdown]
# Your name: REPLACE THIS TEXT
#
# Your Andrew ID: REPLACE THIS TEXT
#
# **Warning: If you leave the above blank, your quiz will not be graded.**

# %% [markdown]
# **Important:** There are 2 problems that can be done in either order:
#
# - Problem 1 (no coding) has 2 parts (a) and (b) that can be done in any order.
# - Problem 2 (mostly coding) has 2 parts (a) and (b) that can be done in any order.

# %% [markdown]
# ## Problem 1: Dimensionality Reduction Conceptual Questions (no coding) [45 points]
#
# *There are code cells in this problem that are strictly for the purposes of displaying images. Your answers should **not** include any code cells or code.*
#
# **Parts (a) and (b) can be done in either order.**
#
# **(a) [20 points across subparts] (PCA)** Consider the following 3D dataset (note that we show this exact same dataset from a few angles so that you can develop some intuition of what this dataset looks like):

# %%
# DO NOT MODIFY THIS CELL; THIS CELL IS JUST TO DISPLAY AN IMAGE
from IPython.display import Image
Image('mystery_siphon.png')

# %% [markdown]
# The color for each data point is just showing the data point's raw z-axis coordinate (so that higher along the z-axis corresponds to a color closer to pink, lower along the z-axis corresponds to a color closer to tan; a z-axis value close to 0 is white).
#
# In case it is not clear, we also show a sketch of the object the 3D dataset corresponds to below (the data points could be thought of as being uniformly distributed across the inside of this object):

# %%
# DO NOT MODIFY THIS CELL; THIS CELL IS JUST TO DISPLAY AN IMAGE
from IPython.display import Image
Image('mystery_moka.png', width=300)

# %% [markdown]
# We also separately show what this 3D dataset looks like if we project all the data to the original x-y, x-z, and y-z planes (resulting in three different 2D scatter plots, where for these particular scatter plots, we do not color any of the points):

# %%
# DO NOT MODIFY THIS CELL; THIS CELL IS JUST TO DISPLAY AN IMAGE
from IPython.display import Image
Image('mystery_speaker.png')

# %% [markdown]
# **Subpart i [10 points].** Which of the following plots corresponds to the correct 2D PCA representation of the dataset? (Exactly one of these is in fact correct!)

# %%
# DO NOT MODIFY THIS CELL; THIS CELL IS JUST TO DISPLAY AN IMAGE
from IPython.display import Image
Image('mystery_canned_soup.png')

# %% [markdown]
# **Your answer here (specify one of panels A, B, C, D, E, F, G, H, or I):** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Briefly explain how you chose your answer (note that if you choose the correct option but do not give a correct justification here, then you will not receive full credit):** REPLACE THIS TEXT WITH YOUR ANSWER

# %% [markdown]
# **Subpart ii [5 points].** Now suppose that we fit a 3D PCA model to the dataset. Which of the following plots corresponds to the correct 2D scatter plot where the horizontal axis shows the **second** principal component, and the vertical axis shows the **third** principal component? (Exactly one of these is in fact correct!)

# %%
# DO NOT MODIFY THIS CELL; THIS CELL IS JUST TO DISPLAY AN IMAGE
from IPython.display import Image
Image('mystery_catch.png')

# %% [markdown]
# **Your answer here (specify one of panels A, B, C, D, E, F, G, H, or I):** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Briefly explain how you chose your answer (note that if you choose the correct option but do not give a correct justification here, then you will not receive full credit):** REPLACE THIS TEXT WITH YOUR ANSWER

# %% [markdown]
# **Subpart iii [5 points].** For just this subpart, suppose that we were to be told that the original dataset's z-coordinate was actually just noise that does not actually help us understand what the dataset is about. Would using the standardization strategy from "StandardScaler" be a good idea?

# %% [markdown]
# **Your answer here ("yes" or "no"):** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Briefly explain your answer (note that if you choose the correct option but do not give a correct justification here, then you will not receive full credit):** REPLACE THIS TEXT WITH YOUR ANSWER
#
#
# NO, it will amplify the noise

# %% [markdown]
# **(b) [25 points across subparts] (Isomap)** Consider a dataset of 7 points A, B, C, D, E, F, and G. Here is the table of Euclidean distances between every pair of points:

# %%
# DO NOT MODIFY THIS CELL; THIS CELL IS JUST TO DISPLAY AN IMAGE
from IPython.display import Image
Image('mystery_giraffe.png', width=500)

# %% [markdown]
# For example, the Euclidean distance between points D and G is 230.12.

# %% [markdown]
# **Subpart i [10 points].** <font color='red'>**Warning:** For just this subpart (i.e., only for Problem 1(b) subpart i), there is no need to explain your answers and we will only be grading based on your final answers and whether they are correct.</font>
#
# Let's construct a symmetric 2-NN graph. First, for each point A, B, C, D, E, F, and G, write down what each point's two nearest neighbors are:

# %% [markdown]
# **Your answer here for the 2 nearest neighbors of point A:** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your answer here for the 2 nearest neighbors of point B:** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your answer here for the 2 nearest neighbors of point C:** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your answer here for the 2 nearest neighbors of point D:** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your answer here for the 2 nearest neighbors of point E:** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your answer here for the 2 nearest neighbors of point F:** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your answer here for the 2 nearest neighbors of point G:** REPLACE THIS TEXT WITH YOUR ANSWER

# %% [markdown]
# Next, please list the edges (or "roads" as we called then in lecture) that would be added for a 2 nearest neighbor graph. For example, if you think that there are a total of 3 edges that will be added "A-F" (meaning an edge between points A and F), "E-G", and "F-G", then please write your answer as: "A-F, E-G, F-G". Note that "A-F" and "F-A" refer to the same edge so if you include "A-F" in your list, then please do not also include "F-A".

# %% [markdown]
# **Your answer for the list of edges that would be added to construct a symmetric 2-NN graph:** REPLACE THIS TEXT WITH YOUR ANSWER

# %% [markdown]
# **Subpart ii [10 points].** Continuing off of the previous subpart, what is the shortest distance between points B and D if we are only allowed to travel on the edges/roads that are in the symmetric 2-NN graph, and how precisely would be go from B to D?
#
# *For the latter question, if you think that the shortest path goes from B to F to A to D, then you can just write "B->F->A->D".*

# %% [markdown]
# **Your answer here for the shortest distance between points B and D (restricted to traveling on edges/roads of the symmetric 2-NN graph):** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your answer here for the shortest path from point B to point D (restricted to traveling on the edges/roads of the symmetric 2-NN graph):** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your reasoning for how you figured out the distance and path above (including why the path is the shortest):** REPLACE THIS TEXT WITH YOUR ANSWER

# %% [markdown]
# **Subpart iii [5 points].** Suppose that we construct a symmetric 6-NN graph for the data points. What is the shortest distance between points B and E, where we are only allowed to travel on the edges/roads in this symmetric 6-NN graph?

# %% [markdown]
# **Your answer here for the shortest distance between points B and D (restricted to traveling on edges/roads of the symmetric 6-NN graph):** REPLACE THIS TEXT WITH YOUR ANSWER
#
# **Your explanation of how you determined what the shortest distance is:** REPLACE THIS TEXT WITH YOUR ANSWER

# %% [markdown]
# ## Problem 2. Human vs ChatGPT Responses (mostly coding) [55 points, of which 10 are for interpretations/explanations without code]
#
# <font color='red'>**Throughout this problem, do not add any Python `import` statements. In particular, the only `import` statements that are allowed are the ones that are in code cells we have provided where we indicate that the code should not be modified.**</font>
#
# In this problem, we use a mystery dataset that is on human vs ChatGPT responses to questions, and we conduct some exploratory data analysis to understand in what ways answers provided by a human differ from those provided by ChatGPT. Note that we have already preprocessed the dataset using our version of spaCy so that what you will be loaded in consist of a mix of some raw and preprocessed data. *You will not have to run spaCy at all for this problem as a result since we've already run it for you.*
#
# Let's load in some of the partially preprocessed data.

# %%
# DO NOT MODIFY THIS CELL
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pickle

with open('mystery_chiropractor.pkl', 'rb') as f:
    questions, human_answer_tokens, chatgpt_answer_tokens = pickle.load(f)

# %% [markdown]
# *Note that these three particular variables `questions`, `human_answer_tokens`, `chatgpt_answer_tokens` will be used in part (a) of this problem but not in part (b), but understanding what these three variables mean will be very helpful in understanding the additional variables loaded in for part (b).*
#
# The three variables `questions`, `human_answer_tokens`, and `chatgpt_answer_tokens` each contain a Python list.
#
# First off, `questions` is a list of the different questions asked to both a human and to ChatGPT. The `i`-th element corresponds to the `i`-th question asked. For example, here is the 0-th question:

# %%
# DO NOT MODIFY THIS CELL
print(questions[0])
# Out:
# Why is every book I hear about a " NY Times # 1 Best Seller " ? ELI5 : Why is every book I hear about a " NY Times # 1 Best Seller " ? Should n't there only be one " # 1 " best seller ? Please explain like I'm five.

# %% [markdown]
# A human's answer to the 0-th question is stored in `human_answer_tokens[0]`, which we have already tokenized using spaCy (and each token has already been converted to a string). Thus, `human_answer_tokens[0]` is a list of strings. For example, the first 5 tokens are:

# %%
# DO NOT MODIFY THIS CELL
print(human_answer_tokens[0][:5])
# Out:
# ['Basically', 'there', 'are', 'many', 'categories']

# %% [markdown]
# Those are only the first 5 tokens. We could of course also print out the human's full answer to the 0-th question. One way to do this:

# %%
# DO NOT MODIFY THIS CELL
for token in human_answer_tokens[0]:
    print(token, end=' ')
    # `end` is an argument that by default is a new line "\n"; by switching `end` to
    # a space character, after printing each token, we do not create a new line and
    # instead print a space after each token
# Out:
# Basically there are many categories of " Best Seller " . Replace " Best Seller " by something like " Oscars " and every " best seller " book is basically an " oscar - winning " book . May not have won the " Best film " , but even if you won the best director or best script , you 're still an " oscar - winning " film . Same thing for best sellers . Also , IIRC the rankings change every week or something like that . Some you might not be best seller one week , but you may be the next week . I guess even if you do n't stay there for long , you still achieved the status . Hence , # 1 best seller .

# %% [markdown]
# ChatGPT's answer to the 0-th question is similarly stored in `chatgpt_answer_tokens[0]` (also a list of tokens, where each token has already been converted to a string):

# %%
# DO NOT MODIFY THIS CELL
for token in chatgpt_answer_tokens[0]:
    print(token, end=' ')
# Out:
# There are many different best seller lists that are published by various organizations , and the New York Times is just one of them . The New York Times best seller list is a weekly list that ranks the best - selling books in the United States based on sales data from a number of different retailers . The list is published in the New York Times newspaper and is widely considered to be one of the most influential best seller lists in the book industry .
#  It 's important to note that the New York Times best seller list is not the only best seller list out there , and there are many other lists that rank the top - selling books in different categories or in different countries . So it 's possible that a book could be a best seller on one list but not on another .
# ...

# %% [markdown]
# **Parts (a) and (b) could be done in either order. Part (a) depends on the three variables loaded in above (namely `questions`, `human_answer_tokens`, `chatgpt_answer_tokens`).**

# %% [markdown]
# **(a) [30 points across subparts (5 of which are not for coding)]** In this part, our main goal is to try to answer the question "how do the length of answers (in terms of number of tokens) differ between the human answers and ChatGPT answers?" The subparts below build up to answering this question.
#
# **Subpart i. [10 points]** Compute two Python lists `human_lengths` and `chatgpt_lengths`, where `human_lengths[i]` is the number of tokens in the `i`-th human answer `human_answer_tokens[i]`, and `chatgpt_lengths[i]` is the number of tokens in the `i`-th ChatGPT answer `chatgpt_answer_tokens[i]`.

# %%
# <------------------- YOUR CODE HERE ----------------------------->
human_lengths = []
chatgpt_lengths = []
# <------------------- END OF YOUR CODE --------------------------->

# %% [markdown]
# **Subpart ii. [10 points]** Continuing off of the previous subpart, plot a bar chart where the x-axis corresponds to different answer lengths (in terms of number of tokens), and the y-axis gives the raw count for how many human answers achieve the different answer lengths.
#
# For your x-axis in particular, please have it correspond to `range(2000)`. For example, when the x-axis value is 42, the corresponding bar (in the bar chart) should have a height (i.e., a y-axis value) equal to the number of human answers that have number of tokens exactly equal to 42.
#
# Note that we have already written the matplotlib part of the code for you so that you should not have to modify that portion.

# %%
lengths_to_plot = range(2000)  # DO NOT MODIFY; this variable corresponds to the x-axis values

# <------------------- YOUR CODE HERE ----------------------------->
human_bar_chart_y_axis_values = []  # this list needs to be modified and should contain 2000 values
                                    # where the i-th entry stores the number of human answers that
                                    # have exactly i tokens in it
# <------------------- END OF YOUR CODE --------------------------->

# DO NOT MODIFY THE CODE BELOW
plt.bar(lengths_to_plot, human_bar_chart_y_axis_values)
plt.xlabel('Answer length (number of tokens)')
plt.ylabel('Raw count')
plt.title('Human answers')

# %% [markdown]
# **Subpart iii. [5 points]** Repeat the previous subpart except now for the ChatGPT answers, i.e., create a bar plot corresponding to a histogram that shows how often different answer lengths (in terms of number of tokens) appear in ChatGPT answers.

# %%
lengths_to_plot = range(2000)  # DO NOT MODIFY; this variable corresponds to the x-axis values

# <------------------- YOUR CODE HERE ----------------------------->
chatgpt_bar_chart_y_axis_values = []  # this list needs to be modified and should contain 2000 values
                                      # where the i-th entry stores the number of ChatGPT answers that
                                      # have exactly i tokens in it
# <------------------- END OF YOUR CODE --------------------------->

# DO NOT MODIFY THE CODE BELOW
plt.bar(lengths_to_plot, chatgpt_bar_chart_y_axis_values)
plt.xlabel('Answer length (number of tokens)')
plt.ylabel('Raw count')
plt.title('ChatGPT answers')

# %% [markdown]
# **Subpart iv (interpretation) [5 points].** Comparing the bar charts you got from the previous two subparts, briefly explain the difference you see between human answers and ChatGPT answers when it comes to answer lengths (again, measured in number of tokens).

# %% [markdown]
# **Your answer here (do not include code in your answer):** REPLACE THIS TEXT WITH YOUR ANSWER

# %% [markdown]
# **(b) [25 points across subparts (5 of which are not for coding)]** In this part, we aim to understand how often a human (or ChatGPT) answer to a question reuses the named entities that appear in the question. Does ChatGPT tend to mention named entities that appear in a question more often than humans?
#
# First off, recall that the 0-th question is partly about the New York Times (commonly abbreviated "NYT" or "NY Times"):

# %%
# DO NOT MODIFY THIS CELL
print(questions[0])

# %% [markdown]
# We now load in some detected named entities by spaCy.

# %%
# DO NOT MODIFY THIS CELL
import pickle
with open('mystery_squirrel_mountain.pkl', 'rb') as f:
    question_entities, human_answer_entities, chatgpt_answer_entities = pickle.load(f)

# %% [markdown]
# Note that per entity, we have converted to a string already, and we also keep track of its entity label.
#
# For example, the 0-th question has the following detected named entities:

# %%
# DO NOT MODIFY THIS CELL
question_entities[0]

# %% [markdown]
# Meanwhile, the human answer to the 0-th question has the following detected named entities:

# %%
# DO NOT MODIFY THIS CELL
human_answer_entities[0]

# %% [markdown]
# In contrast, the ChatGPT answer to the 0-th question has the following detected named entities:

# %%
# DO NOT MODIFY THIS CELL
chatgpt_answer_entities[0]

# %% [markdown]
# Immediately, we see that there is a slight issue: in the question, "NY Times" is mentioned whereas in the ChatGPT answer, "the New York Times"/"The New York Times" is mentioned. We have provided a mystery function `approximate_match` that given two strings says whether they likely correspond to the same named entity (the function returns either `True` or `False`). *For the purposes of this problem, you do not need to look at the code for `approximate_match` nor do you need to know how it works, but you'll need to use this function.*

# %%
# DO NOT MODIFY THIS CELL
from mystery_coffee_grinder import approximate_match

# %% [markdown]
# Just to give some examples of how this function is used:

# %%
# DO NOT MODIFY THIS CELL
approximate_match('the New York Times', 'NY Times')

# %%
# DO NOT MODIFY THIS CELL
approximate_match('New York Times', 'NYT')

# %%
# DO NOT MODIFY THIS CELL
approximate_match('numpy', 'np')

# %%
# DO NOT MODIFY THIS CELL
approximate_match('95-865', 'Unstructured Data Analytics')

# %%
# DO NOT MODIFY THIS CELL
approximate_match('every week', 'weekly')

# %%
# DO NOT MODIFY THIS CELL
approximate_match('1', 'one')

# %% [markdown]
# As you can see, `approximate_match` is not guaranteed to always return the correct answer but it will be sufficient for the purposes of this problem (after all, spaCy is not guaranteed to always give correct answers either, and we're using spaCy's detected named entities).

# %% [markdown]
# **Subpart i. [10 points]** Write the Python function `compute_number_of_mentions` that has the following inputs:
#
# - `entity`: a named entity's raw text represented as a string
# - `label`: the label corresponding to `entity` and that is represented as a string (e.g., "GPE", "ORG", "DATE", etc)
# - `list_of_entity_label_pairs`: a Python list consisting of tuples of the format (entity raw text as string, label of entity also as a string)
#
# Specifically, the output of the function should be the number of items in the list `list_of_entity_label_pairs` that have the exact same entity label as `label` and whose entity raw text string approximately matches `entity` according to the function `approximate_match`.
#
# For example, `compute_number_of_mentions('NY Times', 'ORG', chatgpt_answer_entities[0])` should give an output of 5 since `('the New York Times', 'ORG')` (or alternatively `('The New York Times', 'ORG')`) is mentioned a total of 5 times in `chatgpt_answer_entities[0]`.

# %%
def compute_number_of_mentions(entity, label, list_of_entity_label_pairs):  # DO NOT MODIFY THIS LINE
    number_of_mentions = 0  # DO NOT MODIFY THIS LINE

    # <------------------- YOUR CODE HERE ----------------------------->
    
    # <------------------- END OF YOUR CODE --------------------------->

    return number_of_mentions  # DO NOT MODIFY THIS LINE

# %% [markdown]
# If your code above works correctly, then the following code cell (that you do not modify) should print out:
#
# ```
# Number of times a named entity in question 130 is mentioned in the human's answer: 17
# Number of times a named entity in question 130 is mentioned in ChatGPT's answer: 20
# ```
#
# Note that the function `compute_total_number_of_mentions` defined below (that you will use later in this problem and that you do not need to modify) counts how many times each named entity that appears in a question is mentioned by either a human or ChatGPT answer.

# %%
# *** DO NOT MODIFY THIS CODE CELL ***
from mystery_coffee_grinder import approximate_unique_entity_label_pairs  # YOU DO NOT NEED TO KNOW WHAT THIS FUNCTION DOES

def compute_total_number_of_mentions(entities_of_specific_question, entities_of_specific_answer):
    return sum([compute_number_of_mentions(entity, label, entities_of_specific_answer)
                for entity, label in approximate_unique_entity_label_pairs(entities_of_specific_question)])

print("Number of times a named entity in question 130 is mentioned in the human's answer:",
      compute_total_number_of_mentions(question_entities[130], human_answer_entities[130]))
print("Number of times a named entity in question 130 is mentioned in ChatGPT's answer:",
      compute_total_number_of_mentions(question_entities[130], chatgpt_answer_entities[130]))

# %% [markdown]
# **Subpart ii [5 points].** What is the average number of times (across the questions) that human answers mention named entities that already appeared in the question asked?
#
# *In case this question is not clear, we are basically asking you to compute the average of `compute_total_number_of_mentions(question_entities[0], human_answer_entities[0])`, `compute_total_number_of_mentions(question_entities[1], human_answer_entities[1])`, and so forth up until the last question.*

# %%
# <------------------- YOUR CODE HERE ----------------------------->
# print out the mean/average

# %% [markdown]
# Your code above should have computed the mean/average for an array of numbers. Write the same code but now computing the standard deviation (you can use `np.std`, which takes as input an array of numbers and outputs their standard deviation).

# %%
# <------------------- YOUR CODE HERE ----------------------------->
# print out the standard deviation

# %% [markdown]
# What is the average and the standard deviation of the number of times (across the questions) that ChatGPT answers mention named entities that already appeared in the question asked? Print your answer out of the format "mean +/- standard deviation".

# %%
# <------------------- YOUR CODE HERE ----------------------------->
# print out mean +/- standard deviation (this time for ChatGPT answers rather than human answers)

# %% [markdown]
# **Subpart iii [5 points].** What fraction of the questions does ChatGPT mention named entities (that appear in the question that it is asked) *more* times than the human answer?

# %%
# <------------------- YOUR CODE HERE ----------------------------->
# print out the fraction

# %% [markdown]
# **Subpart iv (interpretation) [5 points].** Given your answers to the previous two subparts, do you think that ChatGPT tends to mention named entities (that appear in the question that it is asked) more often than humans? Please be sure to explain your answer in relation to your answers to subpart ii **and** subpart iii (specifically, we also want you to mention why your answer to subpart iii is consistent with your results from subpart ii). Note that an answer that only states "yes" or only states "no" without an explanation will not receive full credit.

# %% [markdown]
# **Your answer here (do not include code in your answer):** REPLACE THIS TEXT WITH YOUR ANSWER
